# %%
PMT = float(input("Enter payment amount: "))
R = float(input("Enter Rate (%): "))
n = float(input("Number of times compounded per year: "))
t = float(input("Enter time in years: "))

A = PMT * (((1 + (R/100)/n) ** (n*t) - 1) / ((R/100)/n))

print("Future Value of Annuity =", A)
# Out:
# Enter payment amount:  5
# Enter Rate (%):  5
# Number of times compounded per year:  5
# Enter time in years:  5
# Future Value of Annuity = 141.2159975086169
